# %%
import pandas as pd

df=pd.read_excel("Sales Analysis Report (1) (1) (1).xlsx")
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.rename(columns={"Customer Name Index":"customer"},inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  customer      Channel Currency Code  \
# 0      SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2     SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4     SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
# ...            ...        ...        ...       ...          ...           ...
# 7986  SO - 0005237 2019-12-12 2019-12-16        41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12 2019-12-27        28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12 2019-12-27        30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12 2019-12-25         6  Distributor           USD
# 7990  SO - 0007668 2019-12-12 2019-12-25         4    Wholesale           NZD
#
# ...

# %%
df.rename(columns={"Product  Index":"product"},inplace=True)

# %%
df.rename(columns={"Order Quantity":"Quantity"},inplace=True)

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  customer      Channel Currency Code  \
# 0      SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1     SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2     SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3     SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4     SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
# ...            ...        ...        ...       ...          ...           ...
# 7986  SO - 0005237 2019-12-12 2019-12-16        41    Wholesale           NZD
# 7987  SO - 0005477 2019-12-12 2019-12-27        28  Distributor           AUD
# 7988  SO - 0006936 2019-12-12 2019-12-27        30    Wholesale           NZD
# 7989  SO - 0007126 2019-12-12 2019-12-25         6  Distributor           USD
# 7990  SO - 0007668 2019-12-12 2019-12-25         4    Wholesale           NZD
#
# ...

# %%
df.groupby("Warehouse Code")["Unit Price"].sum()
# Out:
# Warehouse Code
# AXW291    8596388.1
# FLR025    1862492.8
# GUT930    4280683.6
# NXH382    3516166.7
# Name: Unit Price, dtype: float64

# %%
df=df.sort_values(by="product",ascending=False)

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  customer      Channel Currency Code  \
# 2905  SO - 0006624 2018-01-22 2018-01-30        22    Wholesale           AUD
# 5290  SO - 0004912 2018-12-13 2018-12-19        33    Wholesale           NZD
# 7251  SO - 0001358 2019-09-06 2019-09-21         5    Wholesale           EUR
# 1564  SO - 0003022 2017-08-04 2017-08-18        25       Export           NZD
# 2931  SO - 0004183 2018-01-26 2018-02-04        27  Distributor           USD
# ...            ...        ...        ...       ...          ...           ...
# 6354   SO - 000747 2019-05-06 2019-05-12        36  Distributor           EUR
# 2402  SO - 0005251 2017-11-17 2017-11-21         1       Export           USD
# 6349   SO - 000647 2019-05-05 2019-05-19        34    Wholesale           USD
# 1155   SO - 000235 2017-06-11 2017-06-14        24  Distributor           USD
# 6410  SO - 0008085 2019-05-13 2019-05-20        19  Distributor           NZD
#
# ...

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  customer      Channel Currency Code  \
# 2905  SO - 0006624 2018-01-22 2018-01-30        22    Wholesale           AUD
# 5290  SO - 0004912 2018-12-13 2018-12-19        33    Wholesale           NZD
# 7251  SO - 0001358 2019-09-06 2019-09-21         5    Wholesale           EUR
# 1564  SO - 0003022 2017-08-04 2017-08-18        25       Export           NZD
# 2931  SO - 0004183 2018-01-26 2018-02-04        27  Distributor           USD
# ...            ...        ...        ...       ...          ...           ...
# 6354   SO - 000747 2019-05-06 2019-05-12        36  Distributor           EUR
# 2402  SO - 0005251 2017-11-17 2017-11-21         1       Export           USD
# 6349   SO - 000647 2019-05-05 2019-05-19        34    Wholesale           USD
# 1155   SO - 000235 2017-06-11 2017-06-14        24  Distributor           USD
# 6410  SO - 0008085 2019-05-13 2019-05-20        19  Distributor           NZD
#
# ...

# %%
df1=pd.read_excel("location.xlsx")

# %%
df2=pd.read_excel("pro.xlsx")

# %%
df3=pd.read_excel("hr.xlsx")

# %%
df1
# Out:
#    location_ID   Location
# 0          125    chennai
# 1          135     mumbai
# 2          145      noida
# 3          175  bangalore
# 4          187  hyderabad

# %%
df2
# Out:
#      ID projects
# 0  1001     Data
# 1  1002     App
# 2  1003     Data
# 3  1004     App
# 4  1005     Data
# 5  1006     App
# 6  1007     Data
# 7  1008     App
# 8  1009     Data

# %%
df3
# Out:
#      ID     Name     Role  Salary  location_ID
# 0  1001    Selva  Manager   50000          125
# 1  1002     Mani  Manager   50000          165
# 2  1003   Naveen       L1   30000          135
# 3  1004  agustin       A1   20000          125
# 4  1005  vincent       L1   30000          125
# 5  1006   brutus       A1   20000          135
# 6  1007    bruce       L2   25000          165
# 7  1008  abishek       A2   18000          125
# 8  1009  madthan       L2   25000          125

# %%
data=df1.merge(df3,how="right")

# %%
data
# Out:
#    location_ID Location    ID     Name     Role  Salary
# 0          125  chennai  1001    Selva  Manager   50000
# 1          165      NaN  1002     Mani  Manager   50000
# 2          135   mumbai  1003   Naveen       L1   30000
# 3          125  chennai  1004  agustin       A1   20000
# 4          125  chennai  1005  vincent       L1   30000
# 5          135   mumbai  1006   brutus       A1   20000
# 6          165      NaN  1007    bruce       L2   25000
# 7          125  chennai  1008  abishek       A2   18000
# 8          125  chennai  1009  madthan       L2   25000

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  customer      Channel Currency Code  \
# 2905  SO - 0006624 2018-01-22 2018-01-30        22    Wholesale           AUD
# 5290  SO - 0004912 2018-12-13 2018-12-19        33    Wholesale           NZD
# 7251  SO - 0001358 2019-09-06 2019-09-21         5    Wholesale           EUR
# 1564  SO - 0003022 2017-08-04 2017-08-18        25       Export           NZD
# 2931  SO - 0004183 2018-01-26 2018-02-04        27  Distributor           USD
# ...            ...        ...        ...       ...          ...           ...
# 6354   SO - 000747 2019-05-06 2019-05-12        36  Distributor           EUR
# 2402  SO - 0005251 2017-11-17 2017-11-21         1       Export           USD
# 6349   SO - 000647 2019-05-05 2019-05-19        34    Wholesale           USD
# 1155   SO - 000235 2017-06-11 2017-06-14        24  Distributor           USD
# 6410  SO - 0008085 2019-05-13 2019-05-20        19  Distributor           NZD
#
# ...

# %%
df["Channel"].value_counts()
# Out:
# Channel
# Wholesale      4286
# Distributor    2510
# Export         1195
# Name: count, dtype: int64

# %%
df["Channel"].value_counts().idxmax()
# Out:
# 'Wholesale'

# %%
df["Channel"].value_counts().head()
# Out:
# Channel
# Wholesale      4286
# Distributor    2510
# Export         1195
# Name: count, dtype: int64

# %%
total_values=df.groupby("Currency Code")["Total Revenue"].sum().sort_values(ascending=False)

# %%
total_values
# Out:
# Currency Code
# NZD    58149949.9
# USD    44650843.5
# AUD    25905710.8
# EUR    13137386.8
# GBP    12729249.6
# Name: Total Revenue, dtype: float64

# %%
total_values.head(2)
# Out:
# Currency Code
# NZD    58149949.9
# USD    44650843.5
# Name: Total Revenue, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df["OrderNumber"]=pd.to_datetime("OrderNumber",errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          0 non-null      datetime64[ns]
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](3), float64(3), int64(4), object(3)
# memory usage: 811.7+ KB

# %%
df.set_index("OrderDate",inplace=True)

# %%
df
# Out:
#             Ship Date  Customer Name Index      Channel Currency Code  \
# OrderDate
# 2017-01-01 2017-01-13                   28    Wholesale           NZD
# 2017-01-01 2017-01-06                    7  Distributor           NZD
# 2017-01-01 2017-01-05                   12    Wholesale           NZD
# 2017-01-01 2017-01-17                    5    Wholesale           USD
# 2017-01-01 2017-01-07                   27       Export           NZD
# ...               ...                  ...          ...           ...
# 2019-12-12 2019-12-16                   41    Wholesale           NZD
# 2019-12-12 2019-12-27                   28  Distributor           AUD
# 2019-12-12 2019-12-27                   30    Wholesale           NZD
# 2019-12-12 2019-12-25                    6  Distributor           USD
# 2019-12-12 2019-12-25                    4    Wholesale           NZD
#
#            Warehouse Code  Region Index  Product  Index  Order Quantity  \
# OrderDate
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#             Ship Date  Customer Name Index      Channel Currency Code  \
# OrderDate
# 2017-01-01 2017-01-13                   28    Wholesale           NZD
# 2017-01-01 2017-01-06                    7  Distributor           NZD
# 2017-01-01 2017-01-05                   12    Wholesale           NZD
# 2017-01-01 2017-01-17                    5    Wholesale           USD
# 2017-01-01 2017-01-07                   27       Export           NZD
# ...               ...                  ...          ...           ...
# 2019-12-12 2019-12-16                   41    Wholesale           NZD
# 2019-12-12 2019-12-27                   28  Distributor           AUD
# 2019-12-12 2019-12-27                   30    Wholesale           NZD
# 2019-12-12 2019-12-25                    6  Distributor           USD
# 2019-12-12 2019-12-25                    4    Wholesale           NZD
#
#            Warehouse Code  Region Index  Product  Index  Order Quantity  \
# OrderDate
# ...

# %%
plt.plot(df["OrderDate"],df["Warehouse Code"],linestyle="-",color="b")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OrderDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 plt.plot(df["OrderDate"],df["Warehouse Code"],linestyle="-",color="b")
# ...

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
